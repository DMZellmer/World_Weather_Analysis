# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import citipy
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?q={cities[0]}&appid={weather_api_key}"

# %%
   # Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
 # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&London&units=imperial"
    #city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0][("description")]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_weather_description})
            

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | atambua
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | yuryevets
# Processing Record 6 of Set 1 | inuvik
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | hofn
# Processing Record 9 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | zyryanka
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | vostochnyy
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | avera
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | zhigansk
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | garmsar
# Processing Record 25 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 1 | huaihua
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | pimentel
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | porto novo
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | los llanos de aridane
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | leshukonskoye
# Processing Record 39 of Set 1 | copiapo
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | lompoc
# Processing Record 42 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | isla aguada
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | santa rosa
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | rivadavia
# Processing Record 1 of Set 2 | richards bay
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | ardakan
# Processing Record 6 of Set 2 | nangong
# Processing Record 7 of Set 2 | himora
# City not found. Skipping...
# Processing Record 8 of Set 2 | vilyuysk
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | oistins
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | sioux lookout
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | aktau
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | deputatskiy
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | port moresby
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | husavik
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | mayumba
# Processing Record 26 of Set 2 | camacha
# Processing Record 27 of Set 2 | kahului
# Processing Record 28 of Set 2 | mopti
# Processing Record 29 of Set 2 | muswellbrook
# Processing Record 30 of Set 2 | norsup
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | labuan
# Processing Record 33 of Set 2 | kabala
# Processing Record 34 of Set 2 | itainopolis
# Processing Record 35 of Set 2 | scalloway
# City not found. Skipping...
# Processing Record 36 of Set 2 | novopavlovka
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | batemans bay
# Processing Record 41 of Set 2 | port hedland
# Processing Record 42 of Set 2 | karamursel
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | casablanca
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | port augusta
# Processing Record 48 of Set 2 | chimbote
# Processing Record 49 of Set 2 | safaga
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | oussouye
# Processing Record 3 of Set 3 | pitkyaranta
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | ginda
# Processing Record 6 of Set 3 | nara
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | zhigalovo
# Processing Record 9 of Set 3 | goderich
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | bairnsdale
# Processing Record 12 of Set 3 | safford
# Processing Record 13 of Set 3 | buala
# Processing Record 14 of Set 3 | yumen
# Processing Record 15 of Set 3 | bandarbeyla
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | anadyr
# Processing Record 18 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 3 | asau
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | san andres
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | maragogi
# Processing Record 24 of Set 3 | cockburn town
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | kungurtug
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | kieta
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | tilichiki
# Processing Record 31 of Set 3 | sabang
# Processing Record 32 of Set 3 | banda aceh
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | kazerun
# Processing Record 35 of Set 3 | sangar
# Processing Record 36 of Set 3 | kidal
# Processing Record 37 of Set 3 | mehamn
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | seoul
# Processing Record 40 of Set 3 | buraydah
# Processing Record 41 of Set 3 | santiago
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 3 | tabuk
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | ketchikan
# Processing Record 46 of Set 3 | matara
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | olafsvik
# Processing Record 50 of Set 3 | isangel
# Processing Record 1 of Set 4 | hakkari
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | zheleznodorozhnyy
# Processing Record 4 of Set 4 | ossora
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | mandalgovi
# Processing Record 7 of Set 4 | abeche
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | tasiilaq
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | yola
# Processing Record 14 of Set 4 | inhambane
# Processing Record 15 of Set 4 | vallenar
# Processing Record 16 of Set 4 | maniitsoq
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | iquitos
# Processing Record 19 of Set 4 | faridan
# City not found. Skipping...
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | zhob
# Processing Record 22 of Set 4 | superior
# Processing Record 23 of Set 4 | douentza
# Processing Record 24 of Set 4 | vastseliina
# Processing Record 25 of Set 4 | boyolangu
# Processing Record 26 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | juneau
# Processing Record 31 of Set 4 | ahuimanu
# Processing Record 32 of Set 4 | kapaa
# Processing Record 33 of Set 4 | hithadhoo
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | palkino
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | saint-joseph
# Processing Record 38 of Set 4 | axim
# Processing Record 39 of Set 4 | gilgit
# Processing Record 40 of Set 4 | tromso
# Processing Record 41 of Set 4 | caravelas
# Processing Record 42 of Set 4 | terbuny
# Processing Record 43 of Set 4 | mae hong son
# Processing Record 44 of Set 4 | verkhnevilyuysk
# Processing Record 45 of Set 4 | esmeraldas
# Processing Record 46 of Set 4 | varna
# Processing Record 47 of Set 4 | aviemore
# Processing Record 48 of Set 4 | beinamar
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | bozeman
# Processing Record 1 of Set 5 | barreiras
# Processing Record 2 of Set 5 | hole narsipur
# Processing Record 3 of Set 5 | port hawkesbury
# Processing Record 4 of Set 5 | katha
# City not found. Skipping...
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | tadine
# Processing Record 9 of Set 5 | berlevag
# Processing Record 10 of Set 5 | gabu
# Processing Record 11 of Set 5 | simao
# Processing Record 12 of Set 5 | svetlyy
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | horni sucha
# Processing Record 15 of Set 5 | moose factory
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | saratak
# Processing Record 18 of Set 5 | aksu
# Processing Record 19 of Set 5 | lima
# Processing Record 20 of Set 5 | rovaniemi
# Processing Record 21 of Set 5 | matay
# Processing Record 22 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 5 | tawzar
# City not found. Skipping...
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | victoria
# Processing Record 27 of Set 5 | chuy
# Processing Record 28 of Set 5 | nova varos
# Processing Record 29 of Set 5 | khekra
# Processing Record 30 of Set 5 | luganville
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | lujiang
# Processing Record 35 of Set 5 | ashland
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | marquette
# Processing Record 38 of Set 5 | krasnoselkup
# Processing Record 39 of Set 5 | panaba
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | kinanah
# City not found. Skipping...
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | fortuna
# Processing Record 44 of Set 5 | uto
# Processing Record 45 of Set 5 | cheney
# Processing Record 46 of Set 5 | qaqortoq
# Processing Record 47 of Set 5 | valdivia
# Processing Record 48 of Set 5 | praia da vitoria
# Processing Record 49 of Set 5 | lyuban
# Processing Record 50 of Set 5 | machali
# Processing Record 1 of Set 6 | palasbari
# Processing Record 2 of Set 6 | voyvozh
# Processing Record 3 of Set 6 | lindenberg
# Processing Record 4 of Set 6 | bathsheba
# Processing Record 5 of Set 6 | andros town
# Processing Record 6 of Set 6 | biltine
# Processing Record 7 of Set 6 | antofagasta
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | mattru
# Processing Record 10 of Set 6 | bumba
# Processing Record 11 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 6 | kiruna
# Processing Record 13 of Set 6 | petropavlovka
# Processing Record 14 of Set 6 | yenagoa
# Processing Record 15 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 6 | sulangan
# Processing Record 17 of Set 6 | payson
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | gat
# Processing Record 20 of Set 6 | soyo
# Processing Record 21 of Set 6 | baie-comeau
# Processing Record 22 of Set 6 | novyy urengoy
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | luleburgaz
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | palivere
# Processing Record 27 of Set 6 | saint-leu
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | baghdad
# Processing Record 31 of Set 6 | rawson
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 6 | fallon
# Processing Record 36 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 6 | cayenne
# Processing Record 38 of Set 6 | vila franca do campo
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | ilo
# Processing Record 41 of Set 6 | kayunga
# Processing Record 42 of Set 6 | murupara
# Processing Record 43 of Set 6 | naco
# Processing Record 44 of Set 6 | saint-pierre
# Processing Record 45 of Set 6 | dubovskoye
# Processing Record 46 of Set 6 | yalta
# Processing Record 47 of Set 6 | mitsamiouli
# Processing Record 48 of Set 6 | gaoua
# Processing Record 49 of Set 6 | lasem
# Processing Record 50 of Set 6 | dannenberg
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | shemgang
# Processing Record 3 of Set 7 | nelspruit
# Processing Record 4 of Set 7 | greenville
# Processing Record 5 of Set 7 | sakakah
# Processing Record 6 of Set 7 | daru
# Processing Record 7 of Set 7 | raudeberg
# Processing Record 8 of Set 7 | redmond
# Processing Record 9 of Set 7 | wajir
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | taitung
# Processing Record 13 of Set 7 | kudahuvadhoo
# Processing Record 14 of Set 7 | palmer
# Processing Record 15 of Set 7 | salar
# Processing Record 16 of Set 7 | havoysund
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | port macquarie
# Processing Record 20 of Set 7 | tarija
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | iquique
# Processing Record 24 of Set 7 | lensk
# Processing Record 25 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | santa cruz
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | huamachuco
# Processing Record 30 of Set 7 | marawi
# Processing Record 31 of Set 7 | misratah
# Processing Record 32 of Set 7 | ereymentau
# Processing Record 33 of Set 7 | necochea
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | nuuk
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | sandovo
# Processing Record 39 of Set 7 | espera feliz
# Processing Record 40 of Set 7 | waipawa
# Processing Record 41 of Set 7 | kayerkan
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | aquiraz
# Processing Record 44 of Set 7 | keningau
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | lorengau
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | popondetta
# Processing Record 49 of Set 7 | prince george
# Processing Record 50 of Set 7 | yamada
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | tual
# Processing Record 3 of Set 8 | rincon
# Processing Record 4 of Set 8 | acapulco
# Processing Record 5 of Set 8 | ahipara
# Processing Record 6 of Set 8 | kargasok
# Processing Record 7 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 8 of Set 8 | roald
# Processing Record 9 of Set 8 | scarborough
# Processing Record 10 of Set 8 | virginia beach
# Processing Record 11 of Set 8 | kapoeta
# Processing Record 12 of Set 8 | kuznetsk
# Processing Record 13 of Set 8 | kamina
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | touros
# Processing Record 16 of Set 8 | coos bay
# Processing Record 17 of Set 8 | hami
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | jemnice
# Processing Record 20 of Set 8 | omboue
# Processing Record 21 of Set 8 | puerto maldonado
# Processing Record 22 of Set 8 | bogashevo
# Processing Record 23 of Set 8 | klyuchi
# Processing Record 24 of Set 8 | fukue
# Processing Record 25 of Set 8 | kokstad
# Processing Record 26 of Set 8 | lampa
# Processing Record 27 of Set 8 | kondinskoye
# Processing Record 28 of Set 8 | salta
# Processing Record 29 of Set 8 | codrington
# Processing Record 30 of Set 8 | decatur
# Processing Record 31 of Set 8 | sychevka
# Processing Record 32 of Set 8 | kajaani
# Processing Record 33 of Set 8 | karia
# Processing Record 34 of Set 8 | banka
# Processing Record 35 of Set 8 | tamandare
# Processing Record 36 of Set 8 | ormara
# Processing Record 37 of Set 8 | linqiong
# Processing Record 38 of Set 8 | norton
# Processing Record 39 of Set 8 | hualmay
# Processing Record 40 of Set 8 | cajati
# Processing Record 41 of Set 8 | krivosheino
# Processing Record 42 of Set 8 | cochrane
# Processing Record 43 of Set 8 | bowen
# Processing Record 44 of Set 8 | tomatlan
# Processing Record 45 of Set 8 | salinopolis
# Processing Record 46 of Set 8 | airai
# Processing Record 47 of Set 8 | bafra
# Processing Record 48 of Set 8 | labuhan
# Processing Record 49 of Set 8 | westport
# Processing Record 50 of Set 8 | naqadeh
# Processing Record 1 of Set 9 | lovozero
# Processing Record 2 of Set 9 | agadir
# Processing Record 3 of Set 9 | carutapera
# Processing Record 4 of Set 9 | shenjiamen
# Processing Record 5 of Set 9 | talakan
# Processing Record 6 of Set 9 | sorkjosen
# Processing Record 7 of Set 9 | encruzilhada
# Processing Record 8 of Set 9 | sweetwater
# Processing Record 9 of Set 9 | polovinnoye
# Processing Record 10 of Set 9 | drabiv
# Processing Record 11 of Set 9 | taoudenni
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | dzerzhinskoye
# Processing Record 14 of Set 9 | ngunguru
# Processing Record 15 of Set 9 | angoche
# Processing Record 16 of Set 9 | burica
# City not found. Skipping...
# Processing Record 17 of Set 9 | bonnyville
# Processing Record 18 of Set 9 | riyadh
# Processing Record 19 of Set 9 | sur
# Processing Record 20 of Set 9 | lethem
# Processing Record 21 of Set 9 | moore
# Processing Record 22 of Set 9 | suao
# City not found. Skipping...
# Processing Record 23 of Set 9 | itapuranga
# Processing Record 24 of Set 9 | sampit
# Processing Record 25 of Set 9 | sitka
# Processing Record 26 of Set 9 | aksarka
# Processing Record 27 of Set 9 | narayangarh
# Processing Record 28 of Set 9 | dombas
# Processing Record 29 of Set 9 | kirakira
# Processing Record 30 of Set 9 | borogontsy
# Processing Record 31 of Set 9 | slavyanka
# Processing Record 32 of Set 9 | kaeo
# Processing Record 33 of Set 9 | keelung
# Processing Record 34 of Set 9 | verbilki
# Processing Record 35 of Set 9 | stokmarknes
# Processing Record 36 of Set 9 | tornio
# Processing Record 37 of Set 9 | diourbel
# Processing Record 38 of Set 9 | forbes
# Processing Record 39 of Set 9 | klyuchevskiy
# Processing Record 40 of Set 9 | altamont
# Processing Record 41 of Set 9 | belmopan
# Processing Record 42 of Set 9 | phan thiet
# Processing Record 43 of Set 9 | yabelo
# Processing Record 44 of Set 9 | hirara
# Processing Record 45 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 9 | namatanai
# Processing Record 47 of Set 9 | patnos
# Processing Record 48 of Set 9 | cuamba
# Processing Record 49 of Set 9 | xiamen
# Processing Record 50 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 10 | koster
# Processing Record 2 of Set 10 | craig
# Processing Record 3 of Set 10 | kristiansund
# Processing Record 4 of Set 10 | kurilsk
# Processing Record 5 of Set 10 | altonia
# City not found. Skipping...
# Processing Record 6 of Set 10 | bernburg
# Processing Record 7 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | yuxia
# Processing Record 9 of Set 10 | merauke
# Processing Record 10 of Set 10 | sawtell
# Processing Record 11 of Set 10 | corrales
# Processing Record 12 of Set 10 | tazovskiy
# Processing Record 13 of Set 10 | faanui
# Processing Record 14 of Set 10 | woodstock
# Processing Record 15 of Set 10 | teahupoo
# Processing Record 16 of Set 10 | ibadan
# Processing Record 17 of Set 10 | vostok
# Processing Record 18 of Set 10 | nome
# Processing Record 19 of Set 10 | santa barbara
# Processing Record 20 of Set 10 | berga
# Processing Record 21 of Set 10 | baley
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | cadereyta
# Processing Record 24 of Set 10 | sabzevar
# Processing Record 25 of Set 10 | perehonivka
# Processing Record 26 of Set 10 | faya
# Processing Record 27 of Set 10 | zakopane
# Processing Record 28 of Set 10 | lasa
# Processing Record 29 of Set 10 | sobolevo
# Processing Record 30 of Set 10 | half moon bay
# Processing Record 31 of Set 10 | novyy svit
# Processing Record 32 of Set 10 | filadelfia
# Processing Record 33 of Set 10 | fairbanks
# Processing Record 34 of Set 10 | laramie
# Processing Record 35 of Set 10 | ola
# Processing Record 36 of Set 10 | brookhaven
# Processing Record 37 of Set 10 | arrecife
# Processing Record 38 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 10 | homer
# Processing Record 40 of Set 10 | berea
# Processing Record 41 of Set 10 | pemangkat
# Processing Record 42 of Set 10 | cabo san lucas
# Processing Record 43 of Set 10 | opalenica
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | darlawn
# Processing Record 46 of Set 10 | rostovka
# Processing Record 47 of Set 10 | iberia
# Processing Record 48 of Set 10 | mapiripan
# Processing Record 49 of Set 10 | shelburne
# Processing Record 50 of Set 10 | sisimiut
# Processing Record 1 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 11 | barao de melgaco
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | marrakesh
# Processing Record 5 of Set 11 | wajima
# Processing Record 6 of Set 11 | sibu
# Processing Record 7 of Set 11 | poso
# Processing Record 8 of Set 11 | jamnah
# City not found. Skipping...
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | rosarito
# Processing Record 11 of Set 11 | naze
# Processing Record 12 of Set 11 | praya
# Processing Record 13 of Set 11 | moscow
# Processing Record 14 of Set 11 | helena
# Processing Record 15 of Set 11 | tocopilla
# Processing Record 16 of Set 11 | pangnirtung
# Processing Record 17 of Set 11 | komsomolets
# Processing Record 18 of Set 11 | dillon
# Processing Record 19 of Set 11 | heiligenhafen
# Processing Record 20 of Set 11 | okakarara
# Processing Record 21 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 11 | basco
# Processing Record 23 of Set 11 | mazyr
# Processing Record 24 of Set 11 | jiwani
# Processing Record 25 of Set 11 | mahajanga
# Processing Record 26 of Set 11 | nelson bay
# Processing Record 27 of Set 11 | evensk
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | flin flon
# Processing Record 30 of Set 11 | sorong
# Processing Record 31 of Set 11 | celestun
# Processing Record 32 of Set 11 | sile
# Processing Record 33 of Set 11 | high rock
# Processing Record 34 of Set 11 | fort nelson
# Processing Record 35 of Set 11 | mozarlandia
# Processing Record 36 of Set 11 | nouadhibou
# Processing Record 37 of Set 11 | ewa beach
# Processing Record 38 of Set 11 | severodvinsk
# Processing Record 39 of Set 11 | chincholi
# Processing Record 40 of Set 11 | gizo
# Processing Record 41 of Set 11 | bainbridge
# Processing Record 42 of Set 11 | bosaso
# Processing Record 43 of Set 11 | coolum beach
# Processing Record 44 of Set 11 | coutances
# Processing Record 45 of Set 11 | carauari
# Processing Record 46 of Set 11 | ringsted
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | dawson
# Processing Record 49 of Set 11 | ulvik
# Processing Record 50 of Set 11 | nurota
# Processing Record 1 of Set 12 | buturlino
# Processing Record 2 of Set 12 | aanekoski
# Processing Record 3 of Set 12 | orbetello
# Processing Record 4 of Set 12 | pouembout
# Processing Record 5 of Set 12 | balakhninskiy
# Processing Record 6 of Set 12 | lufilufi
# Processing Record 7 of Set 12 | shouguang
# Processing Record 8 of Set 12 | yar-sale
# Processing Record 9 of Set 12 | tautira
# Processing Record 10 of Set 12 | haines junction
# Processing Record 11 of Set 12 | south venice
# Processing Record 12 of Set 12 | kawalu
# Processing Record 13 of Set 12 | christchurch
# Processing Record 14 of Set 12 | takoradi
# Processing Record 15 of Set 12 | inirida
# Processing Record 16 of Set 12 | lodja
# Processing Record 17 of Set 12 | monatele
# City not found. Skipping...
# Processing Record 18 of Set 12 | chapais
# Processing Record 19 of Set 12 | cabra
# Processing Record 20 of Set 12 | constitucion
# Processing Record 21 of Set 12 | aloleng
# Processing Record 22 of Set 12 | saskylakh
# Processing Record 23 of Set 12 | cap malheureux
# Processing Record 24 of Set 12 | saint-francois
# Processing Record 25 of Set 12 | sorland
# Processing Record 26 of Set 12 | kunming
# Processing Record 27 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 28 of Set 12 | alice springs
# Processing Record 29 of Set 12 | davenda
# Processing Record 30 of Set 12 | victor harbor
# Processing Record 31 of Set 12 | uklana mandi
# Processing Record 32 of Set 12 | seminole
# Processing Record 33 of Set 12 | bereda
# Processing Record 34 of Set 12 | tucuman
# Processing Record 35 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 12 | wana
# Processing Record 37 of Set 12 | bauchi
# Processing Record 38 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 39 of Set 12 | alofi
# Processing Record 40 of Set 12 | filingue
# Processing Record 41 of Set 12 | zaysan
# Processing Record 42 of Set 12 | ludza
# Processing Record 43 of Set 12 | anekal
# Processing Record 44 of Set 12 | andenes
# Processing Record 45 of Set 12 | mumbwa
# Processing Record 46 of Set 12 | inta
# Processing Record 47 of Set 12 | sabha
# Processing Record 48 of Set 12 | berdigestyakh
# Processing Record 49 of Set 12 | vulcan
# Processing Record 50 of Set 12 | bikaner
# Processing Record 1 of Set 13 | nishihara
# Processing Record 2 of Set 13 | tierranueva
# Processing Record 3 of Set 13 | muravlenko
# Processing Record 4 of Set 13 | orangeburg
# Processing Record 5 of Set 13 | jasper
# Processing Record 6 of Set 13 | kirs
# Processing Record 7 of Set 13 | dubna
# Processing Record 8 of Set 13 | havre-saint-pierre
# Processing Record 9 of Set 13 | rosario
# Processing Record 10 of Set 13 | edson
# Processing Record 11 of Set 13 | poco das trincheiras
# Processing Record 12 of Set 13 | la ligua
# Processing Record 13 of Set 13 | vestmanna
# Processing Record 14 of Set 13 | plettenberg bay
# Processing Record 15 of Set 13 | waingapu
# Processing Record 16 of Set 13 | eyl
# Processing Record 17 of Set 13 | hit
# Processing Record 18 of Set 13 | vilhena
# Processing Record 19 of Set 13 | kupang
# Processing Record 20 of Set 13 | poum
# Processing Record 21 of Set 13 | itarema
# Processing Record 22 of Set 13 | somerville
# Processing Record 23 of Set 13 | beroroha
# Processing Record 24 of Set 13 | simao dias
# Processing Record 25 of Set 13 | kamenka
# Processing Record 26 of Set 13 | hay river
# Processing Record 27 of Set 13 | sekoma
# Processing Record 28 of Set 13 | bhawanipatna
# Processing Record 29 of Set 13 | manggar
# Processing Record 30 of Set 13 | san quintin
# Processing Record 31 of Set 13 | mitchell
# Processing Record 32 of Set 13 | bjornevatn
# Processing Record 33 of Set 13 | luanda
# Processing Record 34 of Set 13 | alyangula
# Processing Record 35 of Set 13 | prince rupert
# Processing Record 36 of Set 13 | kang
# Processing Record 37 of Set 13 | tanete
# Processing Record 38 of Set 13 | san isidro
# Processing Record 39 of Set 13 | verkhnyaya inta
# Processing Record 40 of Set 13 | susehri
# Processing Record 41 of Set 13 | cacapava do sul
# Processing Record 42 of Set 13 | kuching
# Processing Record 43 of Set 13 | almaznyy
# Processing Record 44 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 13 | gushikawa
# Processing Record 46 of Set 13 | uglovskoye
# Processing Record 47 of Set 13 | luwuk
# Processing Record 48 of Set 13 | ixtapa
# Processing Record 49 of Set 13 | san lorenzo de el escorial
# Processing Record 50 of Set 13 | shumskiy
# Processing Record 1 of Set 14 | zimmi
# Processing Record 2 of Set 14 | aldan
# Processing Record 3 of Set 14 | jos
# Processing Record 4 of Set 14 | alihe
# Processing Record 5 of Set 14 | clinton
# Processing Record 6 of Set 14 | farias brito
# Processing Record 7 of Set 14 | kilindoni
# Processing Record 8 of Set 14 | itupeva
# Processing Record 9 of Set 14 | deniliquin
# Processing Record 10 of Set 14 | karaton
# Processing Record 11 of Set 14 | alugan
# Processing Record 12 of Set 14 | manta
# Processing Record 13 of Set 14 | port keats
# Processing Record 14 of Set 14 | marataizes
# Processing Record 15 of Set 14 | la cruz
# Processing Record 16 of Set 14 | port-gentil
# Processing Record 17 of Set 14 | lyngseidet
# Processing Record 18 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 14 | kamaishi
# Processing Record 20 of Set 14 | isiolo
# Processing Record 21 of Set 14 | kyra
# Processing Record 22 of Set 14 | boden
# Processing Record 23 of Set 14 | amga
# Processing Record 24 of Set 14 | arica
# Processing Record 25 of Set 14 | wanning
# Processing Record 26 of Set 14 | egvekinot
# Processing Record 27 of Set 14 | miri
# Processing Record 28 of Set 14 | halifax
# Processing Record 29 of Set 14 | vao
# Processing Record 30 of Set 14 | karmala
# Processing Record 31 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 14 | sept-iles
# Processing Record 33 of Set 14 | rovnoye
# Processing Record 34 of Set 14 | arawa
# Processing Record 35 of Set 14 | grand-lahou
# Processing Record 36 of Set 14 | lons-le-saunier
# Processing Record 37 of Set 14 | nanortalik
# Processing Record 38 of Set 14 | mahon
# Processing Record 39 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 14 | tabat
# Processing Record 41 of Set 14 | trincomalee
# Processing Record 42 of Set 14 | orativ
# Processing Record 43 of Set 14 | vardo
# Processing Record 44 of Set 14 | badou
# Processing Record 45 of Set 14 | abonnema
# Processing Record 46 of Set 14 | tulum
# Processing Record 47 of Set 14 | coihaique
# Processing Record 48 of Set 14 | balkhash
# Processing Record 49 of Set 14 | gondanglegi
# Processing Record 50 of Set 14 | deming
# Processing Record 1 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | lata
# Processing Record 3 of Set 15 | lazaro cardenas
# Processing Record 4 of Set 15 | kyren
# Processing Record 5 of Set 15 | salima
# Processing Record 6 of Set 15 | cloquet
# Processing Record 7 of Set 15 | srednekolymsk
# Processing Record 8 of Set 15 | talnakh
# Processing Record 9 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 15 | tura
# Processing Record 11 of Set 15 | carballo
# Processing Record 12 of Set 15 | caramay
# Processing Record 13 of Set 15 | aras
# Processing Record 14 of Set 15 | gashua
# Processing Record 15 of Set 15 | beloha
# Processing Record 16 of Set 15 | vinh yen
# Processing Record 17 of Set 15 | impfondo
# Processing Record 18 of Set 15 | oksfjord
# Processing Record 19 of Set 15 | melville
# Processing Record 20 of Set 15 | fernley
# Processing Record 21 of Set 15 | zemio
# Processing Record 22 of Set 15 | sao marcos
# Processing Record 23 of Set 15 | luis gil perez
# Processing Record 24 of Set 15 | kyzyl-mazhalyk
# Processing Record 25 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 15 | cay
# Processing Record 27 of Set 15 | zwedru
# Processing Record 28 of Set 15 | west bay
# Processing Record 29 of Set 15 | shkotovo-22
# City not found. Skipping...
# Processing Record 30 of Set 15 | linhares
# Processing Record 31 of Set 15 | jixi
# Processing Record 32 of Set 15 | voh
# Processing Record 33 of Set 15 | oranjemund
# Processing Record 34 of Set 15 | pathankot
# Processing Record 35 of Set 15 | ikom
# Processing Record 36 of Set 15 | farmington
# Processing Record 37 of Set 15 | lakes entrance
# Processing Record 38 of Set 15 | road town
# Processing Record 39 of Set 15 | nalut
# Processing Record 40 of Set 15 | rayong
# Processing Record 41 of Set 15 | tezu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(30)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Atuona  -9.8000 -139.0333     77.92        70          37
# 1       Bengkulu  -3.8004  102.2655     83.70        66         100
# 2        Atambua  -9.1061  124.8925     85.24        50          12
# 3        Rikitea -23.1203 -134.9692     74.26        83          15
# 4      Yuryevets  57.3201   43.1041     63.95        97          99
# 5         Inuvik  68.3499 -133.7218     50.86        96          90
# 6           Hofn  64.2539  -15.2082     53.58        86         100
# 7      Jamestown  42.0970  -79.2353     74.79        88          20
# 8         Avarua -21.2078 -159.7750     64.45        94          75
# 9     Georgetown   5.4112  100.3354     85.95        74          20
# 10      Zyryanka  65.7500  150.8500     77.77        39          60
# 11  San Patricio  28.0170  -97.5169     85.89        71          24
# 12         Tiksi  71.6872  128.8694     45.41        75          99
# 13    Vostochnyy  55.8167   37.8667     60.98        81          15
# 14       Ushuaia -54.8000  -68.3000     42.46        81          75
# 15  Norman Wells  65.2820 -126.8329     66.24        68          75
# 16         Avera  33.1940  -82.5271     80.47        64           1
# 17         Bluff -46.6000  168.3333     52.81        77          13
# 18      Zhigansk  66.7697  123.3711     73.24        36         100
# 19  Punta Arenas -53.1500  -70.9167     45.28        82          97
# 20      Luderitz -26.6481   15.1594     51.15        70           0
# 21       Garmsar  35.2182   52.3409     95.85        14          26
# 22       Huaihua  27.5494  109.9592     87.30        71         100
# 23          Hilo  19.7297 -155.0900     75.79        88          25
# 24      Pimentel  -6.8367  -79.9342     63.00        85          67
# 25   Port Alfred -33.5906   26.8910     54.03        64          79
# 26    Porto Novo   6.4965    2.6036     78.62        91         100
# 27        Albany  42.6001  -73.9662     73.67        95          93
# 28        Bethel  41.3712  -73.4140     79.92        83           1
# 29   New Norfolk -42.7826  147.0587     58.50        88          96
#
#     Wind Speed Country          Current Weather
# 0        16.31      PF         scattered clouds
# 1         7.34      ID          overcast clouds
# 2         5.19      ID               few clouds
# 3        13.33      PF               light rain
# 4         9.22      RU     heavy intensity rain
# 5         6.91      CA  light intensity drizzle
# 6         9.51      IS          overcast clouds
# 7         1.99      US               few clouds
# 8        16.11      CK          very heavy rain
# 9         8.05      MY               few clouds
# 10        6.46      RU            broken clouds
# 11       10.92      US               few clouds
# 12       16.31      RU          overcast clouds
# 13       11.36      RU               few clouds
# 14       20.71      AR  light intensity drizzle
# 15        3.44      CA            broken clouds
# 16        5.82      US                clear sky
# 17       19.95      NZ               few clouds
# 18        8.48      RU          overcast clouds
# 19       15.55      CL          overcast clouds
# 20       15.28      NA                clear sky
# 21        9.08      IR         scattered clouds
# 22        2.26      CN               light rain
# 23        1.99      US         scattered clouds
# 24        3.00      PE            broken clouds
# 25       10.74      ZA            broken clouds
# 26        4.94      BJ          overcast clouds
# 27        2.66      US          overcast clouds
# 28        0.00      US                clear sky
# 29        8.23      AU          overcast clouds

# %%
# Create the output file (CSV)

# Export the City_Data into a CSV.
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv')
