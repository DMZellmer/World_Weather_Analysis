# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import citipy
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?q={cities[0]}&appid={weather_api_key}"

# %%
   # Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
 # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&London&units=imperial"
    #city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0][("description")]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_weather_description})
            

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | alto araguaia
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | henties bay
# Processing Record 4 of Set 1 | sao joao da barra
# Processing Record 5 of Set 1 | sinnamary
# Processing Record 6 of Set 1 | hervey bay
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | houma
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | bad freienwalde
# Processing Record 15 of Set 1 | la spezia
# Processing Record 16 of Set 1 | kapoeta
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | maningrida
# Processing Record 21 of Set 1 | corinto
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | kwekwe
# Processing Record 27 of Set 1 | muros
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | vestmannaeyjar
# Processing Record 31 of Set 1 | yaan
# Processing Record 32 of Set 1 | tessalit
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | san ramon
# Processing Record 35 of Set 1 | vila velha
# Processing Record 36 of Set 1 | port hardy
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | wollongong
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | elko
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | pangody
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | bastia
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | gambela
# Processing Record 49 of Set 1 | wilkie
# Processing Record 50 of Set 1 | kaduqli
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | caxito
# Processing Record 8 of Set 2 | guarapari
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | faya
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | huarmey
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | tanabe
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | amontada
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | safford
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | kaniama
# Processing Record 26 of Set 2 | abu dhabi
# Processing Record 27 of Set 2 | auki
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | makakilo city
# Processing Record 30 of Set 2 | sterling
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | parincea
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 2 | roma
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | kovdor
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | dawson creek
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | voh
# Processing Record 48 of Set 2 | proletariy
# Processing Record 49 of Set 2 | sangar
# Processing Record 50 of Set 2 | port lincoln
# Processing Record 1 of Set 3 | santo domingo
# Processing Record 2 of Set 3 | moradabad
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | douglas
# Processing Record 5 of Set 3 | yamada
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | rio grande
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | yanam
# Processing Record 13 of Set 3 | ndiekro
# City not found. Skipping...
# Processing Record 14 of Set 3 | skegness
# Processing Record 15 of Set 3 | olavarria
# Processing Record 16 of Set 3 | sept-iles
# Processing Record 17 of Set 3 | sari
# Processing Record 18 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | oxapampa
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | gusino
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | farah
# Processing Record 25 of Set 3 | quatre cocos
# Processing Record 26 of Set 3 | yomou
# Processing Record 27 of Set 3 | bambanglipuro
# Processing Record 28 of Set 3 | nhulunbuy
# Processing Record 29 of Set 3 | salinopolis
# Processing Record 30 of Set 3 | rafai
# Processing Record 31 of Set 3 | saint-louis
# Processing Record 32 of Set 3 | port said
# Processing Record 33 of Set 3 | moose factory
# Processing Record 34 of Set 3 | nome
# Processing Record 35 of Set 3 | zvishavane
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | nargana
# Processing Record 38 of Set 3 | skibotn
# Processing Record 39 of Set 3 | cornwall
# Processing Record 40 of Set 3 | kangaatsiaq
# Processing Record 41 of Set 3 | yarada
# Processing Record 42 of Set 3 | puerto escondido
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | sydney
# Processing Record 45 of Set 3 | santa maria
# Processing Record 46 of Set 3 | sur
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | otorohanga
# Processing Record 49 of Set 3 | sunrise manor
# Processing Record 50 of Set 3 | dunedin
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | ahuimanu
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | santiago del estero
# Processing Record 5 of Set 4 | stornoway
# Processing Record 6 of Set 4 | cap malheureux
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | nosy varika
# Processing Record 10 of Set 4 | benalla
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | maraa
# Processing Record 14 of Set 4 | sena madureira
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | kamen-na-obi
# Processing Record 17 of Set 4 | berlevag
# Processing Record 18 of Set 4 | pemangkat
# Processing Record 19 of Set 4 | parrita
# Processing Record 20 of Set 4 | sambava
# Processing Record 21 of Set 4 | monroe
# Processing Record 22 of Set 4 | takoradi
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | backi jarak
# Processing Record 25 of Set 4 | meulaboh
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | palauig
# Processing Record 29 of Set 4 | komsomolskiy
# Processing Record 30 of Set 4 | roald
# Processing Record 31 of Set 4 | marzuq
# Processing Record 32 of Set 4 | lasa
# Processing Record 33 of Set 4 | cap-haitien
# Processing Record 34 of Set 4 | dabat
# Processing Record 35 of Set 4 | moa
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | henzada
# City not found. Skipping...
# Processing Record 38 of Set 4 | marsh harbour
# Processing Record 39 of Set 4 | sokoto
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | deputatskiy
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | tual
# Processing Record 45 of Set 4 | whitley bay
# Processing Record 46 of Set 4 | havoysund
# Processing Record 47 of Set 4 | port hedland
# Processing Record 48 of Set 4 | paita
# Processing Record 49 of Set 4 | itoman
# Processing Record 50 of Set 4 | butaritari
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | ponta do sol
# Processing Record 4 of Set 5 | oistins
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | khorramshahr
# Processing Record 7 of Set 5 | raudeberg
# Processing Record 8 of Set 5 | lamar
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | litovko
# Processing Record 11 of Set 5 | sao francisco
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 5 | kavarskas
# Processing Record 15 of Set 5 | sakakah
# Processing Record 16 of Set 5 | aktau
# Processing Record 17 of Set 5 | portland
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | asosa
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | port augusta
# Processing Record 23 of Set 5 | geraldton
# Processing Record 24 of Set 5 | atikokan
# Processing Record 25 of Set 5 | gizo
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | black river
# Processing Record 28 of Set 5 | vani
# Processing Record 29 of Set 5 | taksimo
# Processing Record 30 of Set 5 | north las vegas
# Processing Record 31 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | kidal
# Processing Record 33 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 5 | agulu
# Processing Record 35 of Set 5 | qiyang
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | fare
# Processing Record 38 of Set 5 | akyab
# Processing Record 39 of Set 5 | nuuk
# Processing Record 40 of Set 5 | turayf
# Processing Record 41 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 5 | paamiut
# Processing Record 43 of Set 5 | trinidad
# Processing Record 44 of Set 5 | kiama
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | salama
# Processing Record 47 of Set 5 | leh
# Processing Record 48 of Set 5 | coahuayana
# Processing Record 49 of Set 5 | kabinda
# Processing Record 50 of Set 5 | port blair
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | uruacu
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | bjornevatn
# Processing Record 5 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint anthony
# Processing Record 7 of Set 6 | pacifica
# Processing Record 8 of Set 6 | camacha
# Processing Record 9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 6 | grand gaube
# Processing Record 11 of Set 6 | mount isa
# Processing Record 12 of Set 6 | usatove
# Processing Record 13 of Set 6 | qaanaaq
# Processing Record 14 of Set 6 | prince rupert
# Processing Record 15 of Set 6 | nagato
# Processing Record 16 of Set 6 | rafaela
# Processing Record 17 of Set 6 | ribeira grande
# Processing Record 18 of Set 6 | grevesmuhlen
# Processing Record 19 of Set 6 | huangzhai
# Processing Record 20 of Set 6 | sabha
# Processing Record 21 of Set 6 | dickinson
# Processing Record 22 of Set 6 | mango
# Processing Record 23 of Set 6 | shenjiamen
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | tabou
# Processing Record 26 of Set 6 | kamaishi
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | jiazi
# Processing Record 29 of Set 6 | finschhafen
# Processing Record 30 of Set 6 | lazaro cardenas
# Processing Record 31 of Set 6 | garissa
# Processing Record 32 of Set 6 | borogontsy
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | namibe
# Processing Record 35 of Set 6 | fortuna
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | merauke
# Processing Record 40 of Set 6 | isangel
# Processing Record 41 of Set 6 | lorengau
# Processing Record 42 of Set 6 | aksarka
# Processing Record 43 of Set 6 | ormara
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | tiksi
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | baykit
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | biak
# Processing Record 50 of Set 6 | chifeng
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | hofn
# Processing Record 3 of Set 7 | chaozhou
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 7 | rapid valley
# Processing Record 7 of Set 7 | dicabisagan
# Processing Record 8 of Set 7 | behshahr
# Processing Record 9 of Set 7 | codrington
# Processing Record 10 of Set 7 | dingle
# Processing Record 11 of Set 7 | ladario
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | kalamb
# Processing Record 14 of Set 7 | labytnangi
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | igarka
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | dalvik
# Processing Record 19 of Set 7 | luwuk
# Processing Record 20 of Set 7 | indiana
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | mahon
# Processing Record 23 of Set 7 | vrangel
# Processing Record 24 of Set 7 | sarangani
# Processing Record 25 of Set 7 | braesti
# Processing Record 26 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 7 | xifeng
# Processing Record 28 of Set 7 | dukat
# Processing Record 29 of Set 7 | chato
# Processing Record 30 of Set 7 | juarez
# Processing Record 31 of Set 7 | bedford
# Processing Record 32 of Set 7 | husavik
# Processing Record 33 of Set 7 | whitianga
# Processing Record 34 of Set 7 | mvuma
# Processing Record 35 of Set 7 | hede
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | chapais
# Processing Record 38 of Set 7 | palmer
# Processing Record 39 of Set 7 | beringovskiy
# Processing Record 40 of Set 7 | axim
# Processing Record 41 of Set 7 | oromocto
# Processing Record 42 of Set 7 | oulainen
# Processing Record 43 of Set 7 | mont-dore
# Processing Record 44 of Set 7 | umm lajj
# Processing Record 45 of Set 7 | hammerfest
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | tuatapere
# Processing Record 48 of Set 7 | lincoln
# Processing Record 49 of Set 7 | camana
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 2 of Set 8 | hambantota
# Processing Record 3 of Set 8 | moron
# Processing Record 4 of Set 8 | aklavik
# Processing Record 5 of Set 8 | tiznit
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | carutapera
# Processing Record 8 of Set 8 | kenora
# Processing Record 9 of Set 8 | maine-soroa
# Processing Record 10 of Set 8 | ancud
# Processing Record 11 of Set 8 | yamasaki
# Processing Record 12 of Set 8 | burica
# City not found. Skipping...
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | bobon
# Processing Record 16 of Set 8 | santa lucia
# Processing Record 17 of Set 8 | kulhudhuffushi
# Processing Record 18 of Set 8 | najran
# Processing Record 19 of Set 8 | vilyuysk
# Processing Record 20 of Set 8 | pyshchug
# Processing Record 21 of Set 8 | olafsvik
# Processing Record 22 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 8 | sabzevar
# Processing Record 24 of Set 8 | sebinkarahisar
# Processing Record 25 of Set 8 | umtata
# Processing Record 26 of Set 8 | loa janan
# Processing Record 27 of Set 8 | vitre
# Processing Record 28 of Set 8 | ofaqim
# Processing Record 29 of Set 8 | marrakesh
# Processing Record 30 of Set 8 | eyrarbakki
# Processing Record 31 of Set 8 | bud
# Processing Record 32 of Set 8 | kroderen
# City not found. Skipping...
# Processing Record 33 of Set 8 | seoul
# Processing Record 34 of Set 8 | lawrenceburg
# Processing Record 35 of Set 8 | amalapuram
# Processing Record 36 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 8 | vasylivka
# Processing Record 38 of Set 8 | nizhniy kuranakh
# Processing Record 39 of Set 8 | ambovombe
# Processing Record 40 of Set 8 | presidencia roque saenz pena
# Processing Record 41 of Set 8 | irtyshskiy
# Processing Record 42 of Set 8 | bambous virieux
# Processing Record 43 of Set 8 | saint-leu
# Processing Record 44 of Set 8 | huangpu
# Processing Record 45 of Set 8 | beloha
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | zamora
# Processing Record 48 of Set 8 | dayong
# Processing Record 49 of Set 8 | hamilton
# Processing Record 50 of Set 8 | fernley
# Processing Record 1 of Set 9 | saraland
# Processing Record 2 of Set 9 | harrisonville
# Processing Record 3 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 9 | mogadishu
# Processing Record 5 of Set 9 | mathbaria
# Processing Record 6 of Set 9 | hami
# Processing Record 7 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 8 of Set 9 | elizabethtown
# Processing Record 9 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 9 | buraydah
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | rybachiy
# Processing Record 13 of Set 9 | malatya
# Processing Record 14 of Set 9 | shimoda
# Processing Record 15 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 9 | boljarovo
# City not found. Skipping...
# Processing Record 17 of Set 9 | ambalavao
# Processing Record 18 of Set 9 | vanavara
# Processing Record 19 of Set 9 | ambon
# Processing Record 20 of Set 9 | jacareacanga
# Processing Record 21 of Set 9 | madimba
# Processing Record 22 of Set 9 | sampit
# Processing Record 23 of Set 9 | mangrol
# Processing Record 24 of Set 9 | atar
# Processing Record 25 of Set 9 | sorong
# Processing Record 26 of Set 9 | sangin
# Processing Record 27 of Set 9 | srednekolymsk
# Processing Record 28 of Set 9 | basco
# Processing Record 29 of Set 9 | vostok
# Processing Record 30 of Set 9 | ati
# Processing Record 31 of Set 9 | san cristobal
# Processing Record 32 of Set 9 | sao filipe
# Processing Record 33 of Set 9 | vila
# Processing Record 34 of Set 9 | magaria
# Processing Record 35 of Set 9 | cabedelo
# Processing Record 36 of Set 9 | san pedro de ycuamandiyu
# Processing Record 37 of Set 9 | whitefish
# Processing Record 38 of Set 9 | mount gambier
# Processing Record 39 of Set 9 | ewa beach
# Processing Record 40 of Set 9 | kyabe
# Processing Record 41 of Set 9 | palmerston
# Processing Record 42 of Set 9 | moerai
# Processing Record 43 of Set 9 | mae sai
# Processing Record 44 of Set 9 | maumere
# Processing Record 45 of Set 9 | kokopo
# Processing Record 46 of Set 9 | vardo
# Processing Record 47 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | mosetse
# Processing Record 49 of Set 9 | bandarbeyla
# Processing Record 50 of Set 9 | dongsheng
# Processing Record 1 of Set 10 | svetlogorsk
# Processing Record 2 of Set 10 | pangnirtung
# Processing Record 3 of Set 10 | saint-joseph
# Processing Record 4 of Set 10 | cayenne
# Processing Record 5 of Set 10 | afrikanda
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | cape elizabeth
# City not found. Skipping...
# Processing Record 8 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 10 | kununurra
# Processing Record 10 of Set 10 | iberia
# Processing Record 11 of Set 10 | silver city
# Processing Record 12 of Set 10 | manicore
# Processing Record 13 of Set 10 | tiarei
# Processing Record 14 of Set 10 | kalianget
# Processing Record 15 of Set 10 | richards bay
# Processing Record 16 of Set 10 | inverell
# Processing Record 17 of Set 10 | maceio
# Processing Record 18 of Set 10 | teguldet
# Processing Record 19 of Set 10 | januaria
# Processing Record 20 of Set 10 | waipawa
# Processing Record 21 of Set 10 | pahrump
# Processing Record 22 of Set 10 | bubaque
# Processing Record 23 of Set 10 | naberera
# Processing Record 24 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 10 | drymen
# Processing Record 26 of Set 10 | tooele
# Processing Record 27 of Set 10 | nizwa
# Processing Record 28 of Set 10 | maniitsoq
# Processing Record 29 of Set 10 | carauari
# Processing Record 30 of Set 10 | lompoc
# Processing Record 31 of Set 10 | salaya
# Processing Record 32 of Set 10 | winnemucca
# Processing Record 33 of Set 10 | ugoofaaru
# Processing Record 34 of Set 10 | zhuhai
# Processing Record 35 of Set 10 | nioro
# Processing Record 36 of Set 10 | bereda
# Processing Record 37 of Set 10 | ossora
# Processing Record 38 of Set 10 | calama
# Processing Record 39 of Set 10 | tinde
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | casas grandes
# Processing Record 42 of Set 10 | shingu
# Processing Record 43 of Set 10 | amapa
# Processing Record 44 of Set 10 | along
# Processing Record 45 of Set 10 | plettenberg bay
# Processing Record 46 of Set 10 | vigrestad
# Processing Record 47 of Set 10 | san juan de abajo
# Processing Record 48 of Set 10 | dali
# Processing Record 49 of Set 10 | galesong
# Processing Record 50 of Set 10 | cabanas
# Processing Record 1 of Set 11 | bagdarin
# Processing Record 2 of Set 11 | natal
# Processing Record 3 of Set 11 | nha trang
# Processing Record 4 of Set 11 | the valley
# Processing Record 5 of Set 11 | bay roberts
# Processing Record 6 of Set 11 | piacabucu
# Processing Record 7 of Set 11 | padang
# Processing Record 8 of Set 11 | kotri
# Processing Record 9 of Set 11 | longjiang
# Processing Record 10 of Set 11 | eagle pass
# Processing Record 11 of Set 11 | rayevskiy
# Processing Record 12 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 11 | warwick
# Processing Record 14 of Set 11 | mlonggo
# Processing Record 15 of Set 11 | beroroha
# Processing Record 16 of Set 11 | high level
# Processing Record 17 of Set 11 | okulovka
# Processing Record 18 of Set 11 | vila do maio
# Processing Record 19 of Set 11 | semey
# Processing Record 20 of Set 11 | cascais
# Processing Record 21 of Set 11 | kirakira
# Processing Record 22 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 11 | opuwo
# Processing Record 24 of Set 11 | placido de castro
# Processing Record 25 of Set 11 | kemijarvi
# Processing Record 26 of Set 11 | nagothana
# Processing Record 27 of Set 11 | verin
# Processing Record 28 of Set 11 | hay river
# Processing Record 29 of Set 11 | sirok
# Processing Record 30 of Set 11 | tomatlan
# Processing Record 31 of Set 11 | santarem
# Processing Record 32 of Set 11 | gerash
# Processing Record 33 of Set 11 | namatanai
# Processing Record 34 of Set 11 | vorozhba
# Processing Record 35 of Set 11 | saucillo
# Processing Record 36 of Set 11 | wa
# City not found. Skipping...
# Processing Record 37 of Set 11 | morlaix
# Processing Record 38 of Set 11 | itarema
# Processing Record 39 of Set 11 | alvaraes
# Processing Record 40 of Set 11 | yeppoon
# Processing Record 41 of Set 11 | puerto leguizamo
# Processing Record 42 of Set 11 | labuhan
# Processing Record 43 of Set 11 | nacala
# Processing Record 44 of Set 11 | penzance
# Processing Record 45 of Set 11 | burnie
# Processing Record 46 of Set 11 | san ignacio
# Processing Record 47 of Set 11 | acapulco
# Processing Record 48 of Set 11 | ostrovnoy
# Processing Record 49 of Set 11 | zelenoborskiy
# Processing Record 50 of Set 11 | taoudenni
# Processing Record 1 of Set 12 | kitimat
# Processing Record 2 of Set 12 | mbalmayo
# Processing Record 3 of Set 12 | tambopata
# Processing Record 4 of Set 12 | chanasma
# Processing Record 5 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 6 of Set 12 | acari
# Processing Record 7 of Set 12 | katsuura
# Processing Record 8 of Set 12 | baranchinskiy
# Processing Record 9 of Set 12 | bathsheba
# Processing Record 10 of Set 12 | san juan
# Processing Record 11 of Set 12 | madisonville
# Processing Record 12 of Set 12 | hobyo
# Processing Record 13 of Set 12 | mayumba
# Processing Record 14 of Set 12 | aykhal
# Processing Record 15 of Set 12 | touros
# Processing Record 16 of Set 12 | birao
# Processing Record 17 of Set 12 | keti bandar
# Processing Record 18 of Set 12 | sovetskiy
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | jaguarao
# Processing Record 21 of Set 12 | iraray
# Processing Record 22 of Set 12 | zeya
# Processing Record 23 of Set 12 | lucea
# Processing Record 24 of Set 12 | tucuman
# Processing Record 25 of Set 12 | los llanos de aridane
# Processing Record 26 of Set 12 | gewane
# Processing Record 27 of Set 12 | sitka
# Processing Record 28 of Set 12 | todos santos
# Processing Record 29 of Set 12 | kolaras
# Processing Record 30 of Set 12 | lagos
# Processing Record 31 of Set 12 | ambanja
# Processing Record 32 of Set 12 | golden
# Processing Record 33 of Set 12 | puerto penasco
# Processing Record 34 of Set 12 | dargaville
# Processing Record 35 of Set 12 | peniche
# Processing Record 36 of Set 12 | adamovka
# Processing Record 37 of Set 12 | tibati
# Processing Record 38 of Set 12 | barra do garcas
# Processing Record 39 of Set 12 | senanga
# Processing Record 40 of Set 12 | hohhot
# Processing Record 41 of Set 12 | atmakur
# Processing Record 42 of Set 12 | clovis
# Processing Record 43 of Set 12 | am timan
# Processing Record 44 of Set 12 | malka
# Processing Record 45 of Set 12 | derazhnya
# Processing Record 46 of Set 12 | luanda
# Processing Record 47 of Set 12 | mahajanga
# Processing Record 48 of Set 12 | zhezkazgan
# Processing Record 49 of Set 12 | luganville
# Processing Record 50 of Set 12 | walvis bay
# Processing Record 1 of Set 13 | stara vyzhivka
# Processing Record 2 of Set 13 | altagracia de orituco
# Processing Record 3 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 4 of Set 13 | clyde river
# Processing Record 5 of Set 13 | kibala
# Processing Record 6 of Set 13 | hualmay
# Processing Record 7 of Set 13 | sobolevo
# Processing Record 8 of Set 13 | bernalillo
# Processing Record 9 of Set 13 | jackson
# Processing Record 10 of Set 13 | rio tercero
# Processing Record 11 of Set 13 | save
# Processing Record 12 of Set 13 | soe
# Processing Record 13 of Set 13 | magnitogorsk
# Processing Record 14 of Set 13 | khasan
# Processing Record 15 of Set 13 | kutum
# Processing Record 16 of Set 13 | epinal
# Processing Record 17 of Set 13 | harbour breton
# Processing Record 18 of Set 13 | timbiqui
# Processing Record 19 of Set 13 | freeport
# Processing Record 20 of Set 13 | lillooet
# Processing Record 21 of Set 13 | gorontalo
# Processing Record 22 of Set 13 | shelburne
# Processing Record 23 of Set 13 | oranjestad
# Processing Record 24 of Set 13 | sibu
# Processing Record 25 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 13 | noboribetsu
# Processing Record 27 of Set 13 | quibdo
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | buritis
# Processing Record 30 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 31 of Set 13 | mugur-aksy
# Processing Record 32 of Set 13 | baarle-hertog
# Processing Record 33 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 13 | lake havasu city
# Processing Record 35 of Set 13 | nouadhibou
# Processing Record 36 of Set 13 | zhigansk
# Processing Record 37 of Set 13 | urumqi
# Processing Record 38 of Set 13 | jagdispur
# Processing Record 39 of Set 13 | lac-megantic
# Processing Record 40 of Set 13 | huron
# Processing Record 41 of Set 13 | sokode
# Processing Record 42 of Set 13 | wattegama
# Processing Record 43 of Set 13 | grindavik
# Processing Record 44 of Set 13 | christchurch
# Processing Record 45 of Set 13 | idritsa
# Processing Record 46 of Set 13 | havre-saint-pierre
# Processing Record 47 of Set 13 | rawson
# Processing Record 48 of Set 13 | taltal
# Processing Record 49 of Set 13 | gazanjyk
# Processing Record 50 of Set 13 | marienburg
# Processing Record 1 of Set 14 | kyra
# Processing Record 2 of Set 14 | alghero
# Processing Record 3 of Set 14 | marshalltown
# Processing Record 4 of Set 14 | dennery
# Processing Record 5 of Set 14 | point fortin
# Processing Record 6 of Set 14 | mitsamiouli
# Processing Record 7 of Set 14 | lazi
# Processing Record 8 of Set 14 | nishihara
# Processing Record 9 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 14 | beatrice
# Processing Record 11 of Set 14 | maarianhamina
# Processing Record 12 of Set 14 | alugan
# Processing Record 13 of Set 14 | jacqueville
# Processing Record 14 of Set 14 | progreso
# Processing Record 15 of Set 14 | brodick
# Processing Record 16 of Set 14 | bodden town
# Processing Record 17 of Set 14 | thinadhoo
# Processing Record 18 of Set 14 | baruun-urt
# Processing Record 19 of Set 14 | edgewater
# Processing Record 20 of Set 14 | tafresh
# Processing Record 21 of Set 14 | tura
# Processing Record 22 of Set 14 | nantucket
# Processing Record 23 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 14 | vila franca do campo
# Processing Record 25 of Set 14 | catio
# Processing Record 26 of Set 14 | kyzyl-suu
# Processing Record 27 of Set 14 | laukaa
# Processing Record 28 of Set 14 | portobelo
# Processing Record 29 of Set 14 | bowen
# Processing Record 30 of Set 14 | markova
# Processing Record 31 of Set 14 | agadez
# Processing Record 32 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 14 | kalabo
# Processing Record 34 of Set 14 | longyearbyen
# Processing Record 35 of Set 14 | mascota
# Processing Record 36 of Set 14 | nova olinda do norte
# Processing Record 37 of Set 14 | whitehorse
# Processing Record 38 of Set 14 | westport
# Processing Record 39 of Set 14 | pecanha
# Processing Record 40 of Set 14 | sao felix do xingu
# Processing Record 41 of Set 14 | mackay
# Processing Record 42 of Set 14 | lima
# Processing Record 43 of Set 14 | ajdabiya
# Processing Record 44 of Set 14 | maneadero
# Processing Record 45 of Set 14 | high rock
# Processing Record 46 of Set 14 | doha
# Processing Record 47 of Set 14 | half moon bay
# Processing Record 48 of Set 14 | dolores
# Processing Record 49 of Set 14 | hobe sound
# Processing Record 50 of Set 14 | tutoia
# Processing Record 1 of Set 15 | alekseyevka
# Processing Record 2 of Set 15 | nanortalik
# Processing Record 3 of Set 15 | plouzane
# Processing Record 4 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 15 | te anau
# Processing Record 6 of Set 15 | colwyn bay
# Processing Record 7 of Set 15 | reyes
# Processing Record 8 of Set 15 | priiskovyy
# Processing Record 9 of Set 15 | nizhnevartovsk
# Processing Record 10 of Set 15 | kloulklubed
# Processing Record 11 of Set 15 | langres
# Processing Record 12 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 13 of Set 15 | northam
# Processing Record 14 of Set 15 | soyo
# Processing Record 15 of Set 15 | xiongzhou
# Processing Record 16 of Set 15 | parvatsar
# Processing Record 17 of Set 15 | del rio
# Processing Record 18 of Set 15 | biguacu
# Processing Record 19 of Set 15 | alappuzha
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | wladyslawowo
# Processing Record 22 of Set 15 | haywards heath
# Processing Record 23 of Set 15 | teguise
# Processing Record 24 of Set 15 | powell river
# Processing Record 25 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 15 | mirzapur
# Processing Record 27 of Set 15 | sisimiut
# Processing Record 28 of Set 15 | port-gentil
# Processing Record 29 of Set 15 | maralal
# Processing Record 30 of Set 15 | zharkent
# Processing Record 31 of Set 15 | manaus
# Processing Record 32 of Set 15 | olivehurst
# Processing Record 33 of Set 15 | bronnoysund
# Processing Record 34 of Set 15 | koumac
# Processing Record 35 of Set 15 | ust-uda
# Processing Record 36 of Set 15 | bichura
# Processing Record 37 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 15 | burns lake
# Processing Record 39 of Set 15 | nadym
# Processing Record 40 of Set 15 | hinton
# Processing Record 41 of Set 15 | ayan
# Processing Record 42 of Set 15 | darhan
# Processing Record 43 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 44 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 15 | albert lea
# Processing Record 46 of Set 15 | kedrovyy
# Processing Record 47 of Set 15 | arman
# Processing Record 48 of Set 15 | verkhnevilyuysk
# Processing Record 49 of Set 15 | cockburn town
# Processing Record 50 of Set 15 | victoria point
# Processing Record 1 of Set 16 | okhotsk
# Processing Record 2 of Set 16 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 16 | merrill
# Processing Record 4 of Set 16 | yerbogachen
# Processing Record 5 of Set 16 | rio gallegos
# Processing Record 6 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 16 | atambua
# Processing Record 8 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 16 | ploemeur
# Processing Record 10 of Set 16 | george town
# Processing Record 11 of Set 16 | road town
# Processing Record 12 of Set 16 | agadir
# Processing Record 13 of Set 16 | velykyy burluk
# Processing Record 14 of Set 16 | brightwater
# Processing Record 15 of Set 16 | eureka
# Processing Record 16 of Set 16 | mecca
# Processing Record 17 of Set 16 | winneba
# Processing Record 18 of Set 16 | vizinga
# Processing Record 19 of Set 16 | loukhi
# Processing Record 20 of Set 16 | mahibadhoo
# Processing Record 21 of Set 16 | moctezuma
# Processing Record 22 of Set 16 | aljezur
# Processing Record 23 of Set 16 | san patricio
# Processing Record 24 of Set 16 | pontes e lacerda
# Processing Record 25 of Set 16 | nakatsugawa
# Processing Record 26 of Set 16 | yulara
# Processing Record 27 of Set 16 | oriximina
# Processing Record 28 of Set 16 | khaga
# Processing Record 29 of Set 16 | saint-remi
# Processing Record 30 of Set 16 | veracruz
# Processing Record 31 of Set 16 | ranau
# Processing Record 32 of Set 16 | dandong
# Processing Record 33 of Set 16 | abbotsford
# Processing Record 34 of Set 16 | aripuana
# Processing Record 35 of Set 16 | qixia
# Processing Record 36 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 16 | kasungu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(30)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Alto Araguaia -17.3147  -53.2153     92.05        13           6
# 1             Hermanus -34.4187   19.2345     51.80        77           4
# 2          Henties Bay -22.1160   14.2845     58.86        82          13
# 3    Sao Joao Da Barra -21.6403  -41.0511     77.09        79          40
# 4            Sinnamary   5.3833  -52.9500     82.33        80          80
# 5           Hervey Bay -25.2986  152.8535     60.04        76           0
# 6           Kaitangata -46.2817  169.8464     42.51        82          46
# 7              Rikitea -23.1203 -134.9692     73.90        79          17
# 8                Houma  29.5958  -90.7195     91.00        69          75
# 9              Ushuaia -54.8000  -68.3000     37.06        93          75
# 10  Comodoro Rivadavia -45.8667  -67.5000     62.46        20           0
# 11          Georgetown   5.4112  100.3354     78.89        92          20
# 12              Albany  42.6001  -73.9662     91.80        61          54
# 13     Bad Freienwalde  52.7873   14.0304     83.28        50         100
# 14           La Spezia  44.1105    9.8434     87.73        65          11
# 15             Kapoeta   4.7717   33.5903     74.73        76          74
# 16         Provideniya  64.3833 -173.3000     44.24        79         100
# 17           Hithadhoo  -0.6000   73.0833     82.53        73          88
# 18            Tasiilaq  65.6145  -37.6368     44.37        65          89
# 19          Maningrida -12.0667  134.2667     69.66        86           4
# 20             Corinto  37.9407   22.9573     87.91        47           0
# 21             Mataura -46.1927  168.8643     41.49        97          52
# 22          Nikolskoye  59.7035   30.7861     67.89        74           0
# 23              Dikson  73.5069   80.5464     44.10       100         100
# 24           Busselton -33.6500  115.3333     49.05        85          64
# 25              Kwekwe -18.9281   29.8149     59.41        72           0
# 26               Muros  42.7762   -9.0603     84.70        51           6
# 27         Tuktoyaktuk  69.4541 -133.0374     41.00        81          90
# 28              Hobart -42.8794  147.3294     46.26        73          50
# 29      Vestmannaeyjar  63.4427  -20.2734     56.39        88          90
#
#     Wind Speed Country          Current Weather
# 0         7.23      BR                clear sky
# 1        14.85      ZA                clear sky
# 2         9.19      NA               few clouds
# 3        13.06      BR         scattered clouds
# 4        11.01      GF            broken clouds
# 5         3.96      AU                clear sky
# 6         8.95      NZ         scattered clouds
# 7         6.71      PF               few clouds
# 8         9.22      US               light rain
# 9         9.22      AR  heavy intensity drizzle
# 10       14.97      AR                clear sky
# 11        2.30      MY               few clouds
# 12        4.47      US            broken clouds
# 13        1.01      DE          overcast clouds
# 14        3.15      IT               few clouds
# 15        5.10      SS               light rain
# 16        6.46      RU          overcast clouds
# 17       13.29      MV          overcast clouds
# 18        7.94      GL          overcast clouds
# 19        9.51      AU                clear sky
# 20        4.12      GR                clear sky
# 21       11.43      NZ               light rain
# 22        5.48      RU                clear sky
# 23        2.68      RU          overcast clouds
# 24        2.82      AU            broken clouds
# 25       17.34      ZW                clear sky
# 26       11.05      ES                clear sky
# 27       12.66      CA               light rain
# 28        4.00      AU         scattered clouds
# 29        9.22      IS          overcast clouds

# %%
# Create the output file (CSV)

# Export the City_Data into a CSV.
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv')
